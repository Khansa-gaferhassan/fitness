# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'c:\\Users\\24911\\WebScraping'

# %%
df = pd.read_csv(r"C:\Users\24911\WebScraping\dailyActivity_merged.csv")

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.shape
# Out:
# (940, 15)

# %%
df['Id'].nunique()
# Out:
# 33

# %%
df.Id.nunique()
# Out:
# 33

# %%
cols =['Id','ActivityDate'	,'TotalSteps',	'TotalDistance',
         	
         	'FairlyActiveMinutes'	,'LightlyActiveMinutes',	'SedentaryMinutes'	,'VeryActiveMinutes','Calories']

# %%
cols
# Out:
# ['Id',
#  'ActivityDate',
#  'TotalSteps',
#  'TotalDistance',
#  'FairlyActiveMinutes',
#  'LightlyActiveMinutes',
#  'SedentaryMinutes',
#  'VeryActiveMinutes',
#  'Calories']

# %%
df1 = pd.DataFrame(columns=cols)
df1
# Out:
# Empty DataFrame
# Columns: [Id, ActivityDate, TotalSteps, TotalDistance, FairlyActiveMinutes, LightlyActiveMinutes, SedentaryMinutes, VeryActiveMinutes, Calories]
# Index: []

# %%
df =df[cols]

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  FairlyActiveMinutes  \
# 0    1503960366    4/12/2016       13162       8.500000                   13
# 1    1503960366    4/13/2016       10735       6.970000                   19
# 2    1503960366    4/14/2016       10460       6.740000                   11
# 3    1503960366    4/15/2016        9762       6.280000                   34
# 4    1503960366    4/16/2016       12669       8.160000                   10
# ..          ...          ...         ...            ...                  ...
# 935  8877689391     5/8/2016       10686       8.110000                    4
# 936  8877689391     5/9/2016       20226      18.250000                   19
# 937  8877689391    5/10/2016       10733       8.150000                   11
# 938  8877689391    5/11/2016       21420      19.559999                   12
# 939  8877689391    5/12/2016        8064       6.120000                    1
#
# ...

# %%
df.rename(columns={'ActivityDate':'Date'},inplace=True)
# Out:
# C:\Users\24911\AppData\Local\Temp\ipykernel_20644\2554800838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'ActivityDate':'Date'},inplace=True)

# %%
df
# Out:
#              Id       Date  TotalSteps  TotalDistance  FairlyActiveMinutes  \
# 0    1503960366  4/12/2016       13162       8.500000                   13
# 1    1503960366  4/13/2016       10735       6.970000                   19
# 2    1503960366  4/14/2016       10460       6.740000                   11
# 3    1503960366  4/15/2016        9762       6.280000                   34
# 4    1503960366  4/16/2016       12669       8.160000                   10
# ..          ...        ...         ...            ...                  ...
# 935  8877689391   5/8/2016       10686       8.110000                    4
# 936  8877689391   5/9/2016       20226      18.250000                   19
# 937  8877689391  5/10/2016       10733       8.150000                   11
# 938  8877689391  5/11/2016       21420      19.559999                   12
# 939  8877689391  5/12/2016        8064       6.120000                    1
#
# ...

# %%
df['TotalMinutes'] =df.FairlyActiveMinutes +df.LightlyActiveMinutes+df.SedentaryMinutes +df.VeryActiveMinutes
df
# Out:
# C:\Users\24911\AppData\Local\Temp\ipykernel_20644\257643132.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalMinutes'] =df.FairlyActiveMinutes +df.LightlyActiveMinutes+df.SedentaryMinutes +df.VeryActiveMinutes
#              Id       Date  TotalSteps  TotalDistance  FairlyActiveMinutes  \
# 0    1503960366  4/12/2016       13162       8.500000                   13
# 1    1503960366  4/13/2016       10735       6.970000                   19
# 2    1503960366  4/14/2016       10460       6.740000                   11
# 3    1503960366  4/15/2016        9762       6.280000                   34
# 4    1503960366  4/16/2016       12669       8.160000                   10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   Date                  940 non-null    object
#  2   TotalSteps            940 non-null    int64
#  3   TotalDistance         940 non-null    float64
#  4   FairlyActiveMinutes   940 non-null    int64
#  5   LightlyActiveMinutes  940 non-null    int64
#  6   SedentaryMinutes      940 non-null    int64
#  7   VeryActiveMinutes     940 non-null    int64
#  8   Calories              940 non-null    int64
#  9   TotalMinutes          940 non-null    int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 73.6+ KB

# %%
df.Date =pd.to_datetime(df.Date)
df
# Out:
# C:\Users\24911\AppData\Local\Temp\ipykernel_20644\3242858665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Date =pd.to_datetime(df.Date)
#              Id       Date  TotalSteps  TotalDistance  FairlyActiveMinutes  \
# 0    1503960366 2016-04-12       13162       8.500000                   13
# 1    1503960366 2016-04-13       10735       6.970000                   19
# 2    1503960366 2016-04-14       10460       6.740000                   11
# 3    1503960366 2016-04-15        9762       6.280000                   34
# 4    1503960366 2016-04-16       12669       8.160000                   10
# ..          ...        ...         ...            ...                  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   Date                  940 non-null    datetime64[ns]
#  2   TotalSteps            940 non-null    int64
#  3   TotalDistance         940 non-null    float64
#  4   FairlyActiveMinutes   940 non-null    int64
#  5   LightlyActiveMinutes  940 non-null    int64
#  6   SedentaryMinutes      940 non-null    int64
#  7   VeryActiveMinutes     940 non-null    int64
#  8   Calories              940 non-null    int64
#  9   TotalMinutes          940 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(8)
# memory usage: 73.6 KB

# %%
df['DayOfWeek'] =df.Date.dt.day_name()
# Out:
# C:\Users\24911\AppData\Local\Temp\ipykernel_20644\3222984429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'] =df.Date.dt.day_name()

# %%
df
# Out:
#              Id       Date  TotalSteps  TotalDistance  FairlyActiveMinutes  \
# 0    1503960366 2016-04-12       13162       8.500000                   13
# 1    1503960366 2016-04-13       10735       6.970000                   19
# 2    1503960366 2016-04-14       10460       6.740000                   11
# 3    1503960366 2016-04-15        9762       6.280000                   34
# 4    1503960366 2016-04-16       12669       8.160000                   10
# ..          ...        ...         ...            ...                  ...
# 935  8877689391 2016-05-08       10686       8.110000                    4
# 936  8877689391 2016-05-09       20226      18.250000                   19
# 937  8877689391 2016-05-10       10733       8.150000                   11
# 938  8877689391 2016-05-11       21420      19.559999                   12
# 939  8877689391 2016-05-12        8064       6.120000                    1
#
# ...

# %%
df.isna().sum()
# Out:
# Id                      0
# Date                    0
# TotalSteps              0
# TotalDistance           0
# FairlyActiveMinutes     0
# LightlyActiveMinutes    0
# SedentaryMinutes        0
# VeryActiveMinutes       0
# Calories                0
# TotalMinutes            0
# DayOfWeek               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  FairlyActiveMinutes  \
# count  9.400000e+02    940.000000     940.000000           940.000000
# mean   4.855407e+09   7637.910638       5.489702            13.564894
# std    2.424805e+09   5087.150742       3.924606            19.987404
# min    1.503960e+09      0.000000       0.000000             0.000000
# 25%    2.320127e+09   3789.750000       2.620000             0.000000
# 50%    4.445115e+09   7405.500000       5.245000             6.000000
# 75%    6.962181e+09  10727.000000       7.712500            19.000000
# max    8.877689e+09  36019.000000      28.030001           143.000000
#
#        LightlyActiveMinutes  SedentaryMinutes  VeryActiveMinutes     Calories  \
# count            940.000000        940.000000         940.000000   940.000000
# mean             192.812766        991.210638          21.164894  2303.609574
# std              109.174700        301.267437          32.844803   718.166862
# ...

# %%
df['TotalHours'] =round((df.FairlyActiveMinutes +df.LightlyActiveMinutes+df.SedentaryMinutes +df.VeryActiveMinutes)/60,0)
# Out:
# C:\Users\24911\AppData\Local\Temp\ipykernel_20644\1665954801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalHours'] =round((df.FairlyActiveMinutes +df.LightlyActiveMinutes+df.SedentaryMinutes +df.VeryActiveMinutes)/60,0)

# %%
df
# Out:
#              Id       Date  TotalSteps  TotalDistance  FairlyActiveMinutes  \
# 0    1503960366 2016-04-12       13162       8.500000                   13
# 1    1503960366 2016-04-13       10735       6.970000                   19
# 2    1503960366 2016-04-14       10460       6.740000                   11
# 3    1503960366 2016-04-15        9762       6.280000                   34
# 4    1503960366 2016-04-16       12669       8.160000                   10
# ..          ...        ...         ...            ...                  ...
# 935  8877689391 2016-05-08       10686       8.110000                    4
# 936  8877689391 2016-05-09       20226      18.250000                   19
# 937  8877689391 2016-05-10       10733       8.150000                   11
# 938  8877689391 2016-05-11       21420      19.559999                   12
# 939  8877689391 2016-05-12        8064       6.120000                    1
#
# ...

# %%
plt.figure(figsize=(20,6))

# %%
plt.hist(df.DayOfWeek,bins=7,width =.6,align='mid')
plt.xlabel('Day of Week')
plt.ylabel("Freq")
plt.title("Freq by Day of Week")
plt.grid()

# %%
mask =df.drop(['DayOfWeek','Date'],axis=1)

# %%
mask.corr()
# Out:
#                             Id  TotalSteps  TotalDistance  \
# Id                    1.000000    0.185721       0.241000
# TotalSteps            0.185721    1.000000       0.985369
# TotalDistance         0.241000    0.985369       1.000000
# FairlyActiveMinutes   0.051158    0.498693       0.462899
# LightlyActiveMinutes -0.098754    0.569600       0.516300
# SedentaryMinutes     -0.043319   -0.327484      -0.288094
# VeryActiveMinutes     0.303608    0.667079       0.681297
# Calories              0.396671    0.591568       0.644962
# TotalMinutes         -0.048274   -0.017285       0.004523
# TotalHours           -0.048140   -0.018152       0.003513
#
#                       FairlyActiveMinutes  LightlyActiveMinutes  \
# Id                               0.051158             -0.098754
# TotalSteps                       0.498693              0.569600
# TotalDistance                    0.462899              0.516300
# FairlyActiveMinutes              1.000000              0.148820
# ...

# %%
sns.heatmap(mask.corr())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  FairlyActiveMinutes  \
# count  9.400000e+02    940.000000     940.000000           940.000000
# mean   4.855407e+09   7637.910638       5.489702            13.564894
# std    2.424805e+09   5087.150742       3.924606            19.987404
# min    1.503960e+09      0.000000       0.000000             0.000000
# 25%    2.320127e+09   3789.750000       2.620000             0.000000
# 50%    4.445115e+09   7405.500000       5.245000             6.000000
# 75%    6.962181e+09  10727.000000       7.712500            19.000000
# max    8.877689e+09  36019.000000      28.030001           143.000000
#
#        LightlyActiveMinutes  SedentaryMinutes  VeryActiveMinutes     Calories  \
# count            940.000000        940.000000         940.000000   940.000000
# mean             192.812766        991.210638          21.164894  2303.609574
# std              109.174700        301.267437          32.844803   718.166862
# ...

# %%
plt.scatter(mask.TotalSteps,mask.Calories,c=mask.Calories)
plt.xlabel('Steps')
plt.ylabel('Calories')
plt.title('Calories and Total Steps')

median_calories= 2134
median_steps=7405
plt.axhline(median_calories,label ='Median of calories')
plt.axvline(median_steps,label ='Median of Steps',color='r')

# %%
plt.scatter(mask.TotalHours,mask.Calories,c=mask.Calories)
plt.xlabel('Hour')
plt.ylabel('Calories')
plt.title('Calories and Total Hour')

median_calories= 2134
median_hour=24
plt.axhline(median_calories,label ='Median of calories')
plt.axvline(median_hour,label ='Median of hour',color='r')

# %%
df
# Out:
#              Id       Date  TotalSteps  TotalDistance  FairlyActiveMinutes  \
# 0    1503960366 2016-04-12       13162       8.500000                   13
# 1    1503960366 2016-04-13       10735       6.970000                   19
# 2    1503960366 2016-04-14       10460       6.740000                   11
# 3    1503960366 2016-04-15        9762       6.280000                   34
# 4    1503960366 2016-04-16       12669       8.160000                   10
# ..          ...        ...         ...            ...                  ...
# 935  8877689391 2016-05-08       10686       8.110000                    4
# 936  8877689391 2016-05-09       20226      18.250000                   19
# 937  8877689391 2016-05-10       10733       8.150000                   11
# 938  8877689391 2016-05-11       21420      19.559999                   12
# 939  8877689391 2016-05-12        8064       6.120000                    1
#
# ...

# %%
minutes =[df.FairlyActiveMinutes.sum(),df.LightlyActiveMinutes.sum(),df.VeryActiveMinutes.sum(),df.SedentaryMinutes.sum()]
labels11 =['FairlyActiveMinutes','LightlyActiveMinutes','VeryActiveMinutes','SedentaryMinutes']
plt.pie(minutes,labels=labels11,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2cfd4b5b7c0>,
# ...
#  [Text(1.099327612776771, 0.03845516592768736, 'FairlyActiveMinutes'),
#   Text(0.9278983073474831, 0.5907662238328083, 'LightlyActiveMinutes'),
#   Text(0.4807149558937111, 0.9894003897210207, 'VeryActiveMinutes'),
#   Text(-0.9161475838727016, -0.6088297007901401, 'SedentaryMinutes')],
#  [Text(0.5996332433327841, 0.020975545051465826, '1.1%'),
#   Text(0.5061263494622635, 0.32223612209062263, '15.8%'),
#   Text(0.26220815776020606, 0.5396729398478294, '1.7%'),
#   Text(-0.4997168639305644, -0.33208892770371273, '81.3%')])
